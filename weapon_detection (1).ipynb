# %%
# 🔰 Step 1: Clone YOLOv5 Repository & Install Dependencies
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# !pip install -r requirements.txt
# !pip install opencv-python

# ✅ Step 2: Upload Custom Model and Test Image/Video
from google.colab import files

print("📤 Upload your trained YOLOv5 model (e.g., best.pt)")
uploaded = files.upload()

print("📤 Upload a test image or video file (e.g., image.jpg / video.mp4)")
uploaded_media = files.upload()

# 🔍 Step 3: Run Detection
import os

# Replace with actual uploaded model filename
model_path = next((f for f in uploaded if f.endswith('.pt')), None)

# Replace with uploaded media file (image or video)
media_file = next((f for f in uploaded_media if f.endswith(('.jpg', '.png', '.mp4'))), None)

# If media is image
if media_file.endswith(('.jpg', '.png')):
    # !python detect.py --weights {model_path} --img 640 --conf 0.5 --source {media_file}

# If media is video
elif media_file.endswith('.mp4'):
    # !python detect.py --weights {model_path} --img 640 --conf 0.5 --source {media_file}

# 📁 Step 4: View Results
from IPython.display import Image, Video, display

results_dir = 'runs/detect'
latest_dir = sorted(os.listdir(results_dir))[-1]
result_path = os.path.join(results_dir, latest_dir)

# Show image result
for file in os.listdir(result_path):
    if file.endswith(('.jpg', '.png')):
        display(Image(filename=os.path.join(result_path, file)))
    elif file.endswith('.mp4'):
        display(Video(os.path.join(result_path, file), embed=True))
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17372, done.
# remote: Counting objects: 100% (59/59), done.
# remote: Compressing objects: 100% (39/39), done.
# remote: Total 17372 (delta 42), reused 20 (delta 20), pack-reused 17313 (from 3)
# Receiving objects: 100% (17372/17372), 16.25 MiB | 15.25 MiB/s, done.
# Resolving deltas: 100% (11910/11910), done.
# /content/yolov5
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 62.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 58.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 48.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.4 MB/s eta 0:00:00
# ...

# %%
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# !pip install -r requirements.txt
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17372, done.
# remote: Counting objects: 100% (59/59), done.
# remote: Compressing objects: 100% (39/39), done.
# remote: Total 17372 (delta 42), reused 20 (delta 20), pack-reused 17313 (from 3)
# Receiving objects: 100% (17372/17372), 16.24 MiB | 18.38 MiB/s, done.
# Resolving deltas: 100% (11904/11904), done.
# /content/yolov5/yolov5
# ...

# %%
num_classes = 1195  # or whatever the class causing KeyError is
with open("data.yaml", "w") as f:
    f.write("names: [\n")
    for i in range(num_classes):
        f.write(f"  'class_{i}',\n")
    f.write("]\n")

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c1710908-c38d-42d7-a619-587c2a1919eb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c1710908-c38d-42d7-a619-587c2a1919eb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !ls
# Out:
# benchmarks.py	 data.yaml   model.pt	     README.zh-CN.md   tutorial.ipynb
# CITATION.cff	 detect.py   models	     requirements.txt  utils
# classify	 export.py   __pycache__     runs	       val.py
# CONTRIBUTING.md  hubconf.py  pyproject.toml  segment
# data		 LICENSE     README.md	     train.py

# %%
import torch

# Load the model
model_path = "/content/model.pt"  # Adjust if it's inside yolov5/
model = torch.load(model_path, map_location='cpu')

# Check keys and structure
if isinstance(model, dict):
    print("📦 Model keys:", model.keys())
    if 'model' in model:
        print("✅ This is a YOLOv5 PyTorch checkpoint.")
    else:
        print("⚠️ This is a PyTorch model but not YOLOv5 format.")
else:
    print("⚠️ This might be a TorchScript or a different model format.")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-a1634be506f3> in <cell line: 0>()
#       3 # Load the model
#       4 model_path = "/content/model.pt"  # Adjust if it's inside yolov5/
# ----> 5 model = torch.load(model_path, map_location='cpu')
#       6
#       7 # Check keys and structure
#
# /usr/local/lib/python3.11/dist-packages/torch/serialization.py in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1423         pickle_load_args["encoding"] = "utf-8"
#    1424
# -> 1425     with _open_file_like(f, "rb") as opened_file:
#    1426         if _is_zipfile(opened_file):
#    1427             # The zipfile reader is going to advance the current file position.
#
# /usr/local/lib/python3.11/dist-packages/torch/serialization.py in _open_file_like(name_or_buffer, mode)
#     749 def _open_file_like(name_or_buffer, mode):
# ...

# %%
# !pip install ultralytics --upgrade

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8beac730-acd8-4812-b430-92632a1d1a2a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8beac730-acd8-4812-b430-92632a1d1a2a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from ultralytics import YOLO

# Load the model
model = YOLO("model.pt")

# Run inference on the image
results = model("ak002_jpg.rf.c818e643f256b477aca6e6e2e1be67b9.jpg")

# Display the results
results[0].show()
# Out:
# image 1/1 /content/yolov5/yolov5/ak002_jpg.rf.c818e643f256b477aca6e6e2e1be67b9.jpg: 640x640 1 Gun, 15.7ms
# Speed: 2.9ms preprocess, 15.7ms inference, 145.3ms postprocess per image at shape (1, 3, 640, 640)
# <PIL.Image.Image image mode=RGB size=640x640>
